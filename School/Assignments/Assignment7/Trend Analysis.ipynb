# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f as fisher_f
import datetime
from sklearn.linear_model import LinearRegression

# %%
df_daily = pd.read_csv("SAP_weekly_return_volatility_detailed.csv")
df_daily.head(5)
# Out:
#          High         Low        Open       Close     Volume  Adj Close  \
# 0   99.559998   98.339996   98.570000   99.180000   506300.0  94.896118
# 1   96.830002   95.449997   96.730003   95.459999   807800.0  91.336800
# 2   99.199997   96.910004   97.339996   98.739998  1038100.0  94.475128
# 3  100.190002   98.760002   99.440002   99.709999   861600.0  95.403229
# 4  101.480003  100.430000  101.370003  101.269997   548600.0  96.895844
#
#    Return        Date  Week_Number  Year  Day    Weekday  mean_return  \
# 0   0.000  2019-01-02            0  2019    2  Wednesday      -0.1050
# 1  -3.751  2019-01-03            0  2019    3   Thursday      -0.1050
# 2   3.436  2019-01-04            0  2019    4     Friday      -0.1050
# 3   0.982  2019-01-07            1  2019    7     Monday       0.6532
# 4   1.565  2019-01-08            1  2019    8    Tuesday       0.6532
#
#    volatility
# 0    3.594650
# 1    3.594650
# 2    3.594650
# 3    1.153409
# 4    1.153409

# %%
df_daily_copy = df_daily.copy()

# %%
months = list()
for i in range(len(df_daily_copy)):
    date = df_daily_copy["Date"][i]
    months.append(datetime.datetime.strptime(date,"%Y-%m-%d").month)
    
df_daily_copy["Month"] = months
df_daily_copy.head(5)
# Out:
#          High         Low        Open       Close     Volume  Adj Close  \
# 0   99.559998   98.339996   98.570000   99.180000   506300.0  94.896118
# 1   96.830002   95.449997   96.730003   95.459999   807800.0  91.336800
# 2   99.199997   96.910004   97.339996   98.739998  1038100.0  94.475128
# 3  100.190002   98.760002   99.440002   99.709999   861600.0  95.403229
# 4  101.480003  100.430000  101.370003  101.269997   548600.0  96.895844
#
#    Return        Date  Week_Number  Year  Day    Weekday  mean_return  \
# 0   0.000  2019-01-02            0  2019    2  Wednesday      -0.1050
# 1  -3.751  2019-01-03            0  2019    3   Thursday      -0.1050
# 2   3.436  2019-01-04            0  2019    4     Friday      -0.1050
# 3   0.982  2019-01-07            1  2019    7     Monday       0.6532
# 4   1.565  2019-01-08            1  2019    8    Tuesday       0.6532
#
#    volatility  Month
# 0    3.594650      1
# 1    3.594650      1
# 2    3.594650      1
# 3    1.153409      1
# 4    1.153409      1

# %%
def linn_regg(x1,y1):
    x = x1
    y = y1
    x_2 = x[:, np. newaxis ]
    
    lin_reg = LinearRegression ( fit_intercept = True )
    lin_reg.fit(x_2 , y)
    prediction = lin_reg.predict(x_2)
    
    sse = sum((y - prediction)**2)
    
    return sse

# %%
# x = np.array(df_daily_copy[(df_daily_copy["Year"] == 2019) & (df_daily_copy["Month"] == 1)]["Day"])
# y = np.array(df_daily_copy[(df_daily_copy["Year"] == 2019) & (df_daily_copy["Month"] == 1)]["Adj Close"])

# %% [markdown]
# ### Values of L

# %%
l = list()
for i in [2019,2020]:
    for j in range(1,13):
        x = np.array(df_daily_copy[(df_daily_copy["Year"] == i) & (df_daily_copy["Month"] == j)]["Day"])
        y = np.array(df_daily_copy[(df_daily_copy["Year"] == i) & (df_daily_copy["Month"] == j)]["Adj Close"])
        l.append(linn_regg(x,y))

# %% [markdown]
# ### Calculating L1, L2, K, F and P_Value

# %%
def compute(y,m,length,sse):
    l1_dict = dict()
    l2_dict = dict()
    l1l2 = dict()
    for i in range(2, len(np.array(df_daily_copy[(df_daily_copy["Year"] == y) & (df_daily_copy["Month"] == m)]["Day"])) - 2):
        x_l1 = np.array(df_daily_copy[(df_daily_copy["Year"] == y) & (df_daily_copy["Month"] == m)]["Day"])[:i]
        y_l1 = np.array(df_daily_copy[(df_daily_copy["Year"] == y) & (df_daily_copy["Month"] == m)]["Adj Close"])[:i]
        ret1 = linn_regg(x_l1,y_l1)
        l1_dict[i] = ret1

        x_l2 = np.array(df_daily_copy[(df_daily_copy["Year"] == y) & (df_daily_copy["Month"] == m)]["Day"])[i:]
        y_l2 = np.array(df_daily_copy[(df_daily_copy["Year"] == y) & (df_daily_copy["Month"] == m)]["Adj Close"])[i:]
        ret2 = linn_regg(x_l2,y_l2)
        l2_dict[i] = ret2

        l1l2[i] = ret1 + ret2
        
    k = min(l1l2,key=l1l2.get)
    l1 = l1_dict[k]
    l2 = l2_dict[k]
    f = ((sse - (l1 + l2)) / 2) * ((l1 + l2) / (length - 4))**-1
    p_value = fisher_f.cdf(f,2,length-4)
    return[l1,l2,k,f,p_value]

# %%
ind = 0
l1_list = list()
l2_list = list()
k_list = list()
f_list = list()
p_list = list()
for yr in [2019,2020]:
    for mo in range(1,13):
        length1 = len(np.array(df_daily_copy[(df_daily_copy["Year"] == yr) & (df_daily_copy["Month"] == mo)]["Day"]))
        sse_l = l[ind]
        l1, l2, k, f, p_value = compute(yr,mo,length1,sse_l)
        l1_list.append(l1)
        l2_list.append(l2)
        k_list.append(k)
        f_list.append(f)
        p_list.append(p_value)
        ind += 1

# %% [markdown]
# ### 1. take years 1 and 2. For each month, compute the "candidate" days and decide whether there is a significant change of pricing trend in each month. Use 0.9 as critical value.

# %%
years = list(np.repeat(2019,12)) + list(np.repeat(2020,12))
months = list(np.arange(1,13)) + list(np.arange(1,13))
df_final = pd.DataFrame([years,months,l,l1_list,l2_list,k_list,f_list,p_list], \
                        index = ["Year","Month","L","L1","L2","K","F","P_value"]).T

df_final
# Out:
#       Year  Month            L          L1         L2     K           F  \
# 0   2019.0    1.0    60.430568   29.718294   0.174696  18.0    8.683287
# 1   2019.0    2.0    11.291953    5.558311   2.113385   9.0    3.539234
# 2   2019.0    3.0    34.768534    4.764037  11.981176  10.0    9.148777
# 3   2019.0    4.0   486.754365   35.734540   1.731571  16.0  101.930787
# 4   2019.0    5.0    80.920829   15.193921  12.941313  11.0   16.885246
# 5   2019.0    6.0    36.883271    2.833394  23.889758   5.0    3.041593
# 6   2019.0    7.0   127.547770    7.108096  18.300564  12.0   36.178688
# 7   2019.0    8.0    43.746715    0.054137  27.334586   4.0    5.375275
# 8   2019.0    9.0    24.245581    0.040775   9.609699   3.0   12.098977
# 9   2019.0   10.0   212.748568   11.071285  14.777030   8.0   68.691226
# 10  2019.0   11.0     9.311513    1.920284   1.605624   7.0   13.127071
# 11  2019.0   12.0    46.669205   10.405019   2.838438  11.0   21.453528
# 12  2020.0    1.0   146.483099   19.217515   6.417691  14.0   40.070171
# 13  2020.0    2.0   261.929508   13.500514   1.491760  11.0  123.532245
# 14  2020.0    3.0  1456.242759  129.513556  96.817485  15.0   48.907147
# 15  2020.0    4.0   406.518387    7.113100  65.946894   6.0   38.795464
# 16  2020.0    5.0   167.305166   10.022361  22.341696   9.0   33.355796
# 17  2020.0    6.0   154.712335   14.170186  58.244900   8.0   10.228190
# 18  2020.0    7.0   194.772666   50.793211  36.408368  15.0   11.102320
# 19  2020.0    8.0    62.893046   22.228015   5.343424  16.0   10.889300
# 20  2020.0    9.0   162.723662   20.945255  70.226375   5.0    6.670850
# 21  2020.0   10.0  2662.348510   88.978891   9.226945  17.0  234.988928
# 22  2020.0   11.0   120.411087    0.230830  30.728820   4.0   23.114327
# 23  2020.0   12.0    63.950741    9.697773  24.344882  11.0    7.906927
#
#      P_value
# 0   0.997479
# 1   0.944930
# 2   0.997991
# 3   1.000000
# 4   0.999926
# 5   0.924061
# 6   1.000000
# 7   0.985221
# 8   0.999370
# 9   1.000000
# 10  0.999577
# 11  0.999978
# 12  1.000000
# 13  1.000000
# 14  1.000000
# 15  1.000000
# 16  0.999998
# 17  0.998922
# 18  0.999277
# 19  0.999097
# 20  0.992731
# 21  1.000000
# 22  0.999981
# 23  0.996568

# %% [markdown]
# ### 2. how many months exhibit significant price changes for your stock ticker.
#
# * All 24 months exhibit significant change for my stock. The is a trend change in every month.

# %% [markdown]
# ### 3. are there more "changes" in year 1 or in year 2?
#
# * Both years 2019 and 2020 have same no. of chanegs 12.
